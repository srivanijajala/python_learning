# %%
a = 10
b = 20
print(a+b)

# %%
x = "hello"
y = "world"
print(x+y)

# %%
a = 20
b = 15
print(a-b)

# %%
print(10*5)
print(500/10)

# %%
# floor division
print(10//3)

# %%
print(10%3)

# %%
# 2 to the power of 3(it will give less number)
print(2**3)

# %%
print(38//3)
print(38/3)

# %%
print(-38//3)

# %%
import math
print(math.floor(2.9))

# %%
print(math.ceil(2.2))

# %%
print(round(3.1423,2))

# %%
a = [1,2]
a+= [3]
a
