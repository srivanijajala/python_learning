# %%
a=10
b=2.5 
c=a+b
print(c)
print(type(c))

# %%
a="10"
b=5

print(a+str(b))

# %%
# bool + int 
x=True+5
print (x,type(x))

# %%
#int + float
x=10+3.7
print (x,type(x))

# %%
#int + complex 
x=5+3j 
print (x,type(x))
# Out:
# (5+3j) <class 'complex'>

# %%
#float + complex
x=2.5+4j
print (x,type(x))
# Out:
# (2.5+4j) <class 'complex'>
